# %% [markdown]
# This notebook will be used for the capstone course in IBM's Data Science certification on Coursera

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
